# %%
import requests
import time

# %%
tistory_url = 'https://www.tistory.com/apis/post/write?'

parameters = {
    'access_token' : 'df5a6d880a8051c3f9482bb4d5fc01aa_e2889430643dce45bf2f1ac783199427',
    'blogName' : 'kay-honeytips',
    'title' : '소린이 내꺼',
    'content' : '<p data-ke-size="size16">&lt;&lt;&gt;&gt;</p> \
    <h2 data-ke-size="size26">소린그</h2><p data-ke-size="size16">&nbsp;</p>\
    <hr contenteditable="false" data-ke-type="horizontalRule" data-ke-style="style3" />\
    <div><center><!-- health tip issue 상단 -->\
    <p data-ke-size="size16">&nbsp;</p>\
    <script>\
         (adsbygoogle = window.adsbygoogle || []).push({});\
    </script>\
    </center></div>\
    <hr contenteditable="false" data-ke-type="horizontalRule" data-ke-style="style3" />\
    <p data-ke-size="size16">린그;</p>\
    <p data-ke-size="size16">&nbsp;</p>\
    <p data-ke-size="size16">&nbsp;</p>\
    <p data-ke-size="size16">&nbsp;</p>\
    <p data-ke-size="size16">&nbsp;</p>\
    <p data-ke-size="size16">&nbsp;</p>\
    <hr contenteditable="false" data-ke-type="horizontalRule" data-ke-style="style3" />\
    <div><center><!-- health tipissue 중단 -->\
    <p data-ke-size="size16">&nbsp;</p>\
    <script>\
         (adsbygoogle = window.adsbygoogle || []).push({});\
    </script></center></div>\
    <hr contenteditable="false" data-ke-type="horizontalRule" data-ke-style="style3" />\
    <p data-ke-size="size16">&nbsp;</p>\
    <p data-ke-size="size16">&nbsp;</p>\
    <p data-ke-size="size16">&nbsp;</p>\
    <p data-ke-size="size16">&nbsp;</p>\
    <p data-ke-size="size16">&nbsp;</p>\
    <p data-ke-size="size16">&nbsp;</p>\
    <p data-ke-size="size16">&nbsp;</p>\
    <p data-ke-size="size16">&nbsp;</p>\
    <hr contenteditable="false" data-ke-type="horizontalRule" data-ke-style="style3" />\
    <div><center><!-- health tipissue 하단 -->\
    <p data-ke-size="size16">&nbsp;</p>\
    <script>\
         (adsbygoogle = window.adsbygoogle || []).push({});\
    </script></center></div>\
    <hr contenteditable="false" data-ke-type="horizontalRule" data-ke-style="style3" />\
    <p data-ke-size="size16">&nbsp;</p>\
    <p data-ke-size="size16">&nbsp;</p>\
    <p data-ke-size="size16">&nbsp;</p>',
    'visibility' : 0, # 0: 비공개(default), 1: 보호, 3: 발행
    'category' : 0, # 0: 카테고리명(default)
    'published' : time.time(),
    'tag' : '소린, 러버',
    'acceptComment': '0' # 0: 댓글 비허용(default), 1: 허용
}

# %%
response = requests.post(tistory_url, params=parameters)
print(response.text)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <tistory><status>200</status><postId>14</postId><url>https://health.tipissue.com/14</url></tistory>

# %%
def check_complete(arg_resp):
    tmp_txt = arg_resp.text
    
    str_idx = tmp_txt.find('<tistory><status>') + 17 # len = 17
    end_idx = tmp_txt.find('</status><postId>')
    
    print(str_idx)
    print(end_idx)
    
    posting_result = tmp_txt[str_idx:end_idx]
    print(tmp_txt[str_idx:end_idx])
    
    if posting_result == '200':
        print("Success")
    else:
        print("Fail")

# %%
check_complete(response)
# Out:
# 56
# 59
# 200
# Success
